# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install pandas
# %pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_twitch = pd.read_sql_table('twitch_games', 'sqlite:///../data/data.sqlite')
df_games = pd.read_sql_table('popular_video_games', 'sqlite:///../data/data.sqlite')
df_merged = pd.read_sql_table('merged', 'sqlite:///../data/data.sqlite')

# %% [markdown]
# ### Look at the first rows

# %%
df_twitch.head(10)
# Out:
#                                Game  Month  Year  Hours_watched  \
# 0                 League of Legends      1  2016       94377226
# 1  Counter-Strike: Global Offensive      1  2016       47832863
# 2                            Dota 2      1  2016       45185893
# 3                       Hearthstone      1  2016       39936159
# 4       Call of Duty: Black Ops III      1  2016       16153057
# 5                         Minecraft      1  2016       10231056
# 6                 World of Warcraft      1  2016        8771452
# 7                 Z1: Battle Royale      1  2016        7894571
# 8                           FIFA 16      1  2016        6988475
# 9                      StarCraft II      1  2016        6567126
#
#    Hours_streamed  Peak_viewers  Peak_channels  Avg_viewers  Avg_channels
# 0         1362044        530270           2903       127021          1833
# 1          830105        372654           2197        64378          1117
# ...

# %%
df_games.head(10)
# Out:
#                                        Title  Release_Date  \
# 0                                 Elden Ring  Feb 25, 2022
# 1    The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2                                      Hades  Dec 07, 2018
# 3                              Hollow Knight  Feb 24, 2017
# 4                                  Undertale  Sep 15, 2015
# 5                                  Minecraft  Nov 18, 2011
# 6                                      Omori  Dec 25, 2020
# 7  The Legend of Zelda: Tears of the Kingdom  May 12, 2023
# 8                            Resident Evil 4  Mar 24, 2023
# 9                             NieR: Automata  Feb 23, 2017
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# ...

# %%
df_merged.head(10)
# Out:
#                 Game  Month  Year  Hours_watched  Hours_streamed  \
# 0  League of Legends      1  2016       94377226         1362044
# 1  League of Legends      2  2016       93154772         1266715
# 2  League of Legends      3  2016       94514511         1264029
# 3  League of Legends      4  2016       88389049         1217250
# 4  League of Legends      5  2016       80679320         1196096
# 5  League of Legends      6  2016       81348505         1037242
# 6  League of Legends      7  2016       77871713         1004238
# 7  League of Legends      8  2016       81684707         1097258
# 8  League of Legends      9  2016       81064642         1087244
# 9  League of Legends     10  2016      104305242         1155966
#
#    Peak_viewers  Peak_channels  Avg_viewers  Avg_channels              Title  \
# 0        530270           2903       127021          1833  League of Legends
# 1        475784           2712       134035          1822  League of Legends
# ...

# %% [markdown]
# ### Data exploration
# Print some basic information about the data.

# %%
df_twitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17855 entries, 0 to 17854
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Game            17854 non-null  object
#  1   Month           17855 non-null  int64
#  2   Year            17855 non-null  int64
#  3   Hours_watched   17855 non-null  int64
#  4   Hours_streamed  17855 non-null  int64
#  5   Peak_viewers    17855 non-null  int64
#  6   Peak_channels   17855 non-null  int64
#  7   Avg_viewers     17855 non-null  int64
#  8   Avg_channels    17855 non-null  int64
# dtypes: int64(8), object(1)
# memory usage: 1.2+ MB

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         60000 non-null  object
#  1   Release_Date  60000 non-null  object
#  2   Platforms     60000 non-null  object
#  3   Genres        60000 non-null  object
#  4   Plays         60000 non-null  object
# dtypes: object(5)
# memory usage: 2.3+ MB

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15158 entries, 0 to 15157
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Game            15158 non-null  object
#  1   Month           15158 non-null  int64
#  2   Year            15158 non-null  int64
#  3   Hours_watched   15158 non-null  int64
#  4   Hours_streamed  15158 non-null  int64
#  5   Peak_viewers    15158 non-null  int64
#  6   Peak_channels   15158 non-null  int64
#  7   Avg_viewers     15158 non-null  int64
#  8   Avg_channels    15158 non-null  int64
#  9   Title           15158 non-null  object
#  10  Release_Date    15158 non-null  object
#  11  Platforms       15158 non-null  object
#  12  Genres          15158 non-null  object
#  13  Plays           15158 non-null  object
# dtypes: int64(8), object(6)
# memory usage: 1.6+ MB
